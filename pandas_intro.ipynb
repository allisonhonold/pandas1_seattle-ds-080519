# %% [markdown]
# # Let's Use Pandas!

# %% [markdown]
# First, import pandas.

# %%
import pandas as pd

# %% [markdown]
# Now read in the heart dataset.

# %%
heart = pd.read_csv('heart.csv')

# %% [markdown]
# What does .head( ) do? What do you learn about the dataset by using it here?

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# What about .tail( )? What about .info( ) and .describe( )?

# %%
heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# What can we figure out / guess about the different columns?

# %% [markdown]
# Here's a row that our engineer accidentally left out of the .csv file, expressed as a Python dictionary:

# %%
extra_rows = {'age': [40, 30], 'sex': [1, 0], 'cp': [0, 0], 'trestbps': [120, 130], 'chol': [240, 200],
             'fbs': [0, 0], 'restecg': [1, 0], 'thalach': [120, 122], 'exang': [0, 1],
              'oldpeak': [0.1, 1.0], 'slope': [1, 1], 'ca': [0, 1], 'thal': [2, 3], 'target': [0, 0]}
extra_rows
# Out:
# {'age': [40, 30],
#  'sex': [1, 0],
#  'cp': [0, 0],
#  'trestbps': [120, 130],
#  'chol': [240, 200],
#  'fbs': [0, 0],
#  'restecg': [1, 0],
#  'thalach': [120, 122],
#  'exang': [0, 1],
#  'oldpeak': [0.1, 1.0],
#  'slope': [1, 1],
#  'ca': [0, 1],
#  'thal': [2, 3],
#  'target': [0, 0]}

# %% [markdown]
# How can we add this to the bottom of our dataset?

# %%
two_rows = pd.DataFrame(extra_rows)
two_rows

heart_tot = pd.concat([heart, two_rows])
heart_tot.tail()

heart_tot_index = heart_tot.reset_index(drop = True)
heart_tot_index.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
# 303   40    1   0       120   240    0        1      120      0      0.1
# 304   30    0   0       130   200    0        0      122      1      1.0
#
#      slope  ca  thal  target
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
# 303      1   0     2       0
# 304      1   1     3       0

# %%
# Out:
# 2    142
# 1    142
# 0     21
# Name: slope, dtype: int64

# %% [markdown]
# How many different values does have slope have? What about sex? And target?

# %%
heart_tot_index['slope'].value_counts()
# Out:
# 2    142
# 1    142
# 0     21
# Name: slope, dtype: int64

# %%
heart_tot_index['sex'].value_counts()
# Out:
# 1    208
# 0     97
# Name: sex, dtype: int64

# %% [markdown]
# Let's add a new column to our dataset called "test". Set all of its values to 0.

# %%
heart_tot_index.drop(columns = ['test', 'test1'], inplace = True)
heart_tot_index.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ## Filtering

# %% [markdown]
# We can use filtering techniques to see only certain rows of our data. If we wanted to see only the rows for patients 70 years of age or older, we can simply type:

# %%
heart[heart['age'] >= 70]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 145   70    1   1       156   245    0        0      143      0      0.0
# 151   71    0   0       112   149    0        1      125      0      1.6
# 225   70    1   0       145   174    0        1      125      1      2.6
# 234   70    1   0       130   322    0        0      109      0      2.4
# 238   77    1   0       125   304    0        0      162      1      0.0
# 240   70    1   2       160   269    0        1      112      1      2.9
#
#      slope  ca  thal  target
# 25       2   2     2       1
# 60       2   1     2       1
# 129      2   1     2       1
# 144      1   0     2       1
# 145      2   0     2       1
# 151      1   0     2       1
# 225      0   0     3       0
# 234      1   3     2       0
# 238      2   3     2       0
# 240      1   1     3       0

# %% [markdown]
# Use '&' for "and" and '|' for "or".

# %%
# Display the patients who are 70 over as well as the patients whose trestbps score is greater than 170.
heart[(heart['trestbps'] > 170) | (heart['age'] >= 70)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 8     52    1   2       172   199    1        1      162      0      0.5
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 101   59    1   3       178   270    0        0      145      0      4.2
# 110   64    0   0       180   325    0        1      154      1      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 151   71    0   0       112   149    0        1      125      0      1.6
# 203   68    1   2       180   274    1        0      150      1      1.6
# 223   56    0   0       200   288    1        0      133      1      4.0
# 238   77    1   0       125   304    0        0      162      1      0.0
# 241   59    0   0       174   249    0        1      143      1      0.0
# 248   54    1   1       192   283    0        0      195      0      0.0
# 260   66    0   0       178   228    1        1      165      1      1.0
# 266   55    0   0       180   327    0        2      117      1      3.4
#
#      slope  ca  thal  target
# 8        2   0     3       1
# 25       2   2     2       1
# 60       2   1     2       1
# 101      0   0     3       1
# 110      2   0     2       1
# 129      2   1     2       1
# 144      1   0     2       1
# 151      1   0     2       1
# 203      1   0     3       0
# 223      0   2     3       0
# 238      2   3     2       0
# 241      1   0     2       0
# 248      2   1     3       0
# 260      1   2     3       0
# 266      1   0     2       0

# %% [markdown]
# ## .loc() and .iloc()

# %% [markdown]
# We can use .loc to get, say, the first ten values of the age and trestbps columns:

# %%
heart.loc[:9, ['age', 'trestbps']]
# Out:
#    age  trestbps
# 0   63       145
# 1   37       130
# 2   41       130
# 3   56       120
# 4   57       120
# 5   57       140
# 6   56       140
# 7   44       120
# 8   52       172
# 9   57       150

# %% [markdown]
# .iloc() is used for selecting locations in the DataFrame **by number**:

# %%
# How would we get the same slice as just above by using .iloc() instead of .loc()?

# %%
heart.iloc[:10,[0,3]]
# Out:
#    age  trestbps
# 0   63       145
# 1   37       130
# 2   41       130
# 3   56       120
# 4   57       120
# 5   57       140
# 6   56       140
# 7   44       120
# 8   52       172
# 9   57       150

# %% [markdown]
# ## Plotting

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Let's plot a histogram of patients' ages:

# %%
age_hist = plt.hist(heart['age'], bins = 20)

# %% [markdown]
# Let's plot cholesterol vs. age

# %%
plt.scatter(heart['age'], heart['chol'], c=heart['target'])

# %% [markdown]
# Let's use the target column to color our points:

# %% [markdown]
# ## Let's find a .csv file online and experiment with it.

# %%
# Out:
# b'Skipping line 558: expected 28 fields, saw 32\nSkipping line 699: expected 28 fields, saw 29\nSkipping line 2267: expected 28 fields, saw 29\nSkipping line 2268: expected 28 fields, saw 29\nSkipping line 3281: expected 28 fields, saw 29\nSkipping line 3416: expected 28 fields, saw 29\nSkipping line 4179: expected 28 fields, saw 29\nSkipping line 4461: expected 28 fields, saw 30\nSkipping line 5036: expected 28 fields, saw 29\nSkipping line 6214: expected 28 fields, saw 29\nSkipping line 6239: expected 28 fields, saw 31\nSkipping line 6240: expected 28 fields, saw 31\nSkipping line 6422: expected 28 fields, saw 29\nSkipping line 6819: expected 28 fields, saw 29\nSkipping line 8149: expected 28 fields, saw 31\nSkipping line 8607: expected 28 fields, saw 29\n'
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 65: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-64-319fc6722033> in <module>()
# ----> 1 ann_arbor_construction_pmts = pd.read_csv('/Users/allisonhonold/Downloads/ANN_ARBOR_CONSTRUCTION_PERMITS.csv', error_bad_lines=False)
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 65: invalid start byte

# %% [markdown]
# ## Your turn!
